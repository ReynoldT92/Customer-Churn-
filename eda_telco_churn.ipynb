# %% [markdown]
# # Customer Churn

# %% [markdown]
# # Setup & data loading

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
# Load data
csv_path = 'WA_Fn-UseC_-Telco-Customer-Churn.csv'
if not os.path.exists(csv_path):
	raise FileNotFoundError(f"File not found: {csv_path}. Make sure the CSV file is in the notebook working directory: {os.getcwd()}")
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.describe().T
# Out:
#                  count       mean        std    min   25%    50%    75%  \
# SeniorCitizen   7043.0   0.162147   0.368612   0.00   0.0   0.00   0.00
# tenure          7043.0  32.371149  24.559481   0.00   9.0  29.00  55.00
# MonthlyCharges  7043.0  64.761692  30.090047  18.25  35.5  70.35  89.85
#
#                    max
# SeniorCitizen     1.00
# tenure           72.00
# MonthlyCharges  118.75

# %% [markdown]
# # Data quality checks

# %%
misisng_values = df.isnull().sum()
print("Missing values in each column:")
print(misisng_values)
# Out:
# Missing values in each column:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# # data cleaning

# %%
# fix 'totalcharges' column
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
missing_total_charges = df['TotalCharges'].isnull().sum()
print(f"Missing values in 'TotalCharges' after conversion: {missing_total_charges}")
# Out:
# Missing values in 'TotalCharges' after conversion: 11

# %%
# Drop rows with missing 'TotalCharges' values
df.dropna(subset=['TotalCharges'], inplace=True)

# %%
drop_cols = ['customerID']
# drop only if column exists to avoid KeyError
df.drop(columns=drop_cols, inplace=True, errors='ignore')

# %%
# separate numerical and categorical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# %% [markdown]
# # Identifying the Churn Drivers
#
# ## Which customers are likely to churn?

# %%
# 1. Visualize Churn Distribution (Class Imbalance)
plt.figure(figsize=(6, 4))
# ensure palette is provided as a string name supported by seaborn/matplotlib
# using 'viridis' to avoid any undefined-name issues
sns.countplot(x='Churn', data=df, palette='viridis')
plt.title('Distribution of Customer Churn')
plt.show()

# 2. The "Smoking Gun": Contract Type vs Churn
plt.figure(figsize=(10, 6))
# use hue='Churn' to color by churn
sns.countplot(x='Contract', hue='Churn', data=df, palette='Set2')
plt.title('Churn by Contract Type')
plt.show()
# Out:
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/757897186.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette='viridis')

# %% [markdown]
# # Monthly Charges vs Churn

# %%
plt.figure(figsize=(8, 6))

# Adding hue='Churn' and legend=False tells Seaborn to color the boxes 
# and prevents an unnecessary legend from appearing on the side.
sns.boxplot(x='Churn', y='MonthlyCharges', data=df, hue='Churn', palette='Set2', legend=False)

plt.title('Monthly Charges vs Churn')
plt.show()

# %% [markdown]
# # Analyzing Numerical Relationships
# ### Does paying more make you leave ?Do new customers leave faster ?

# %%
# Tenure vs Churn
plt.figure(figsize=(10, 6))
sns.kdeplot(df[df['Churn'] == 'No']['tenure'], label='Stayed', fill=True)
sns.kdeplot(df[df['Churn'] == 'Yes']['tenure'], label='Churned', fill=True)
plt.title('Tenure Distribution: Stayed vs Churned')
plt.xlabel('Months with Company')
plt.legend()
plt.show()

# %% [markdown]
# # Correlation Heat Map

# %%
# Quick conversion for correlation check
df_temp = df.copy()

# Convert TotalCharges to numeric (there are string values), coerce errors to NaN
df_temp['TotalCharges'] = pd.to_numeric(df_temp['TotalCharges'], errors='coerce')

# Map target to numeric
df_temp['Churn'] = df_temp['Churn'].map({'Yes': 1, 'No': 0})

# Select numeric columns only to avoid non-numeric fields like customerID
num_cols = df_temp.select_dtypes(include=['number']).columns.tolist()
# Ensure 'Churn' is present
if 'Churn' not in num_cols:
    num_cols.append('Churn')

# Correlation with the target
churn_corr = df_temp[num_cols].corr()[['Churn']].sort_values(by='Churn', ascending=False)

plt.figure(figsize=(4, max(4, len(churn_corr) * 0.4)))
sns.heatmap(churn_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Features Correlated with Churn')
plt.show()

# %% [markdown]
# # Overall Churn rate

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.734215
# Yes    0.265785
# Name: proportion, dtype: float64

# %% [markdown]
# # Churn Rate by Contract type

# %%
contract_churn = (
    df.groupby('Contract')['Churn']
      .value_counts(normalize=True)
      .unstack()
      * 100
)

contract_churn.round(2)
# Out:
# Churn              No    Yes
# Contract
# Month-to-month  57.29  42.71
# One year        88.72  11.28
# Two year        97.15   2.85

# %% [markdown]
# # Median Charges vs Tenure

# %%
df['Churn'].value_counts(normalize=True)

df.groupby('Contract')['Churn'].value_counts(normalize=True)

df.groupby('Churn')[['MonthlyCharges','tenure']].median()
# Out:
#        MonthlyCharges  tenure
# Churn
# No              64.45    38.0
# Yes             79.65    10.0

# %%
summary = df.groupby('Churn')[['MonthlyCharges','tenure']].median()

summary.plot(kind='bar', figsize=(8,5))
plt.title('Median Monthly Charges & Tenure by Churn')
plt.ylabel('Median Value')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Univariate Analysis: Categorical features

# %%
# Identify all categorical columns except the target
cat_cols = df.select_dtypes(include=['object']).columns.tolist()
if 'Churn' in cat_cols: cat_cols.remove('Churn')

# Calculate number of rows needed for the grid (4 columns wide)
n_rows = (len(cat_cols) + 3) // 4 

fig, axes = plt.subplots(n_rows, 4, figsize=(20, n_rows * 4))
axes = axes.flatten()

for i, col in enumerate(cat_cols):
    # This line sorts the categories by count in ascending order
    # Change [::-1] to [:] if you want descending instead
    order_list = df[col].value_counts(ascending=True).index
    
    sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
    
    axes[i].set_title(f'Distribution of {col}', fontsize=12)
    axes[i].set_xlabel('')
    axes[i].tick_params(axis='x', rotation=45)

# Remove empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/3906189233.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, ax=axes[i], palette='viridis', order=order_list)

# %% [markdown]
# # Univariate Analysis:Numerical features

# %%
num_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

plt.figure(figsize=(18, 5))
for i, col in enumerate(num_cols):
    plt.subplot(1, 3, i+1)
    sns.histplot(df[col], kde=True, color='teal')
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Correlation heatmap of numerical features

# %%
# Create the heatmap for numerical features
plt.figure(figsize=(10, 8))
# We only use numerical columns and the mapped 'Churn'
df_corr = df.copy()
df_corr['Churn'] = df_corr['Churn'].map({'Yes': 1, 'No': 0})
sns.heatmap(df_corr.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# # The Relationship between Contract Risk and Price Sensitivity

# %%
# Custom palette: Green for "No" (Safe), Red/Orange for "Yes" (Risk)
custom_colors = ['#27ae60', '#e67e22'] 

# Create two subplots: left for contract churn stacked bars, right for median price gap
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
ax0, ax1 = axes  # ax0: contract churn, ax1: price gap

# Plot stacked bar chart on the left axis
contract_churn.plot(kind='bar', 
                    stacked=True, 
                    color=custom_colors, 
                    ax=ax0, 
                    edgecolor='white')

# Formatting for a "Sick" professional look on left plot
ax0.set_title('Churn Risk by Contract Type', fontsize=15, pad=12, fontweight='bold')
ax0.set_ylabel('Percentage of Customers (%)', fontsize=12)
ax0.set_xlabel('Contract Category', fontsize=12)
ax0.set_xticklabels(ax0.get_xticklabels(), rotation=0)
ax0.legend(title='Churned?', labels=['No (Stayed)', 'Yes (Risk)'], loc='upper right')

# Add percentage labels inside the bars for extra clarity
for p in ax0.patches:
    width = p.get_width()
    height = p.get_height()
    x = p.get_x()
    y = p.get_y()
    if height > 5:  # Only label if the segment is big enough to see
        ax0.text(x + width/2, 
                 y + height/2, 
                 f'{height:.1f}%', 
                 ha='center', va='center', 
                 color='white', fontweight='bold')

# Price Gap (Median) on the right axis
# 'bluebrown' is not a valid seaborn palette name. Use a valid palette list or a builtin palette name.
sns.barplot(
    x='Churn',
    y='MonthlyCharges',
    data=df,
    ax=ax1,
    palette=["#1fb43d", "#D8D2C5"],  # blue for 'No', orange for 'Yes'
    estimator='median'
)
ax1.set_title('The Price Gap: Median Monthly Charges')
ax1.set_xlabel('Churn')
ax1.set_ylabel('Median Monthly Charges')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/00/c54qzf757tzdyqs5hr4n94vc0000gn/T/ipykernel_48101/2720204083.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
